# %%
# Write a program that prints We like Python's turtles! 1000 times.

for i in range(1000):
    print("We like Python's turtles!")
# Out:
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# We like Python's turtles!
# ...

# %%
# Give three attributes of your cellphone object. Give three methods of your cellphone.
# -attributes => color, size, brand
# -methods => call, browse, text

# %%
# Write a program that uses a for loop to print
months = ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"]
for month in months:
    print(f"One of the months of the year is {month}")
# Out:
# One of the months of the year is January
# One of the months of the year is February
# One of the months of the year is March
# One of the months of the year is April
# One of the months of the year is May
# One of the months of the year is June
# One of the months of the year is July
# One of the months of the year is August
# One of the months of the year is September
# One of the months of the year is October
# One of the months of the year is November
# One of the months of the year is December

# %%
# Suppose our turtle tess is at heading 0 — facing east. We execute the statement tess.left(3645). 
# What does tess do, and what is her final heading?
final_heading =  3645%360
print(final_heading)

import turtle
w = turtle.Screen()
tess = turtle.Turtle()

# tess.left(3645)
# Out:
# 45

# %%
# Assume you have the assignment xs = [12, 10, 32, 3, 66, 17, 42, 99, 20]
xs = [12, 10, 32, 3, 66, 17, 42, 99, 20]
# Write a loop that prints each of the numbers on a new line.
for x in xs:
    print(x)
# Out:
# 12
# 10
# 32
# 3
# 66
# 17
# 42
# 99
# 20

# %%
# Write a loop that prints each number and its square on a new line.
for x in xs:
    print(x, x**2)
# Out:
# 12 144
# 10 100
# 32 1024
# 3 9
# 66 4356
# 17 289
# 42 1764
# 99 9801
# 20 400

# %%
# Write a loop that adds all the numbers from the list into a variable called total. 
# You should set the total variable to have the value 0 before you start adding them up, 
# and print the value in total after the loop has completed.

total = 0
for x in xs:
    total += x
print(total)
# Out:
# 301

# %%
# Print the product of all the numbers in the list. (product means all multiplied together)
product = 1

for x in xs:
    product *= x
print(product)
# Out:
# 1074879590400

# %%
# Use for loops to make a turtle draw these regular polygons 
# (regular means all sides the same lengths, all angles the same):
# An equilateral triangle
for i in range(3):
    tess.forward(60)
    tess.left(360/3)

# %%
# A square
for i in range(4):
    tess.forward(60)
    tess.left(360/4)

# %%
# A hexagon (six sides)
for i in range(6):
    tess.forward(60)
    tess.left(360/6)

# %%
# An octagon (eight sides)
for i in range(8):
    tess.forward(60)
    tess.left(360/8)

# %%
# A drunk pirate makes a random turn and then takes 100 steps forward, makes another random turn,
# takes another 100 steps, turns another random amount, etc. A social science student records the 
# angle of each turn before the next 100 steps are taken. 
# Her experimental data is [160, -43, 270, -97, -43, 200, -940, 17, -86]. 
# (Positive angles are counter-clockwise.) Use a turtle to draw the path taken by our drunk friend.

data = [160, -43, 270, -97, -43, 200, -940, 17, -86]
for i in data:
    total = 0
    tess.forward(100)
    tess.left(i)
    total += i
print(f"The driver is heading {total%360} left")
# Out:
# The driver is heading 274 left

# %%
# If you were going to draw a regular polygon with 18 sides, 
# what angle would you need to turn the turtle at each corner?
# 20
for i in range(18):
    tess.forward(60)
    tess.left(360/18)

# %%
# Write a program to draw a shape like this:
for i in range(5):
    tess.forward(60)
    tess.left(72)
turtle.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-31-d37f4a9672b5> in <module>
#       1 # Write a program to draw a shape like this:
#       2 for i in range(5):
# ----> 3     tess.forward(60)
#       4     tess.left(72)
#       5 turtle.mainloop()
#
# /opt/anaconda3/lib/python3.7/turtle.py in forward(self, distance)
#    1635         (-50.00,0.00)
#    1636         """
# -> 1637         self._go(distance)
#    1638
#    1639     def back(self, distance):
#
# /opt/anaconda3/lib/python3.7/turtle.py in _go(self, distance)
#    1603         """move turtle forward by specified distance"""
#    1604         ende = self._position + self._orient * distance
# -> 1605         self._goto(ende)
#    1606
#    1607     def _rotate(self, angle):
#
# /opt/anaconda3/lib/python3.7/turtle.py in _goto(self, end)
#    3156                       (self.currentLineItem,
# ...
